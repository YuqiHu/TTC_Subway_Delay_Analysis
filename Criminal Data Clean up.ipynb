# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
# Read the CSV into a DataFrame
criminal_data_raw = pd.read_csv(os.path.join("Criminal", 'Assault_Open_Data.csv'))
criminal_data_raw.head()
# Out:
#               X             Y  OBJECTID EVENT_UNIQUE_ID  \
# 0 -8.837009e+06  5.414638e+06         1  GO-20141265238
# 1 -8.832733e+06  5.419701e+06         2  GO-20141259834
# 2 -8.836444e+06  5.410819e+06         3  GO-20141262027
# 3 -8.836897e+06  5.412101e+06         4  GO-20141259951
# 4 -8.851435e+06  5.422186e+06         5  GO-20141261561
#
#               REPORT_DATE                OCC_DATE  REPORT_YEAR REPORT_MONTH  \
# 0  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00         2014      January
# 1  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00         2014      January
# 2  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00         2014      January
# 3  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00         2014      January
# 4  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00         2014      January
#
#    REPORT_DAY  REPORT_DOY  ... UCR_CODE  UCR_EXT                OFFENCE  \
# 0           1           1  ...     1430      100                Assault
# 1           1           1  ...     1420      100    Assault With Weapon
# 2           1           1  ...     1430      100                Assault
# 3           1           1  ...     1460      100  Assault Peace Officer
# 4           1           1  ...     1420      100    Assault With Weapon
#
#   MCI_CATEGORY  HOOD_158                      NEIGHBOURHOOD_158 HOOD_140  \
# 0      Assault        98                    Rosedale-Moore Park       98
# 1      Assault        55                       Thorncliffe Park       55
# 2      Assault       166  St Lawrence-East Bayfront-The Islands       77
# 3      Assault       170                     Yonge-Bay Corridor       76
# 4      Assault       154               Oakdale-Beverley Heights       26
#
#                         NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 0                Rosedale-Moore Park (98) -79.384206  43.670798
# 1                   Thorncliffe Park (55) -79.345795  43.703684
# 2  Waterfront Communities-The Island (77) -79.379131  43.645981
# 3                Bay Street Corridor (76) -79.383200  43.654313
# 4               Downsview-Roding-CFB (26) -79.513797  43.719824
#
# [5 rows x 31 columns]

# %%
#create a new data frame contains the useful columns below
#OCC_DATE
#LOCATION_TYPE
#PREMISES_TYPE
#OFFENCE
#NEIGHBOURHOOD_140
#LONG_WGS84
#LAT_WGS84


criminal_data_sorted = criminal_data_raw[['OCC_DATE','LOCATION_TYPE','PREMISES_TYPE',
                                        'OFFENCE','NEIGHBOURHOOD_140','LONG_WGS84','LAT_WGS84']]

criminal_data_sorted.head()
# Out:
#                  OCC_DATE                                      LOCATION_TYPE  \
# 0  2014/01/01 05:00:00+00                                 Ttc Subway Station
# 1  2014/01/01 05:00:00+00                                   Bar / Restaurant
# 2  2014/01/01 05:00:00+00  Streets, Roads, Highways (Bicycle Path, Privat...
# 3  2014/01/01 05:00:00+00  Streets, Roads, Highways (Bicycle Path, Privat...
# 4  2014/01/01 05:00:00+00  Commercial Dwelling Unit (Hotel, Motel, B & B,...
#
#   PREMISES_TYPE                OFFENCE  \
# 0       Transit                Assault
# 1    Commercial    Assault With Weapon
# 2       Outside                Assault
# 3       Outside  Assault Peace Officer
# 4    Commercial    Assault With Weapon
#
#                         NEIGHBOURHOOD_140  LONG_WGS84  LAT_WGS84
# 0                Rosedale-Moore Park (98)  -79.384206  43.670798
# 1                   Thorncliffe Park (55)  -79.345795  43.703684
# 2  Waterfront Communities-The Island (77)  -79.379131  43.645981
# 3                Bay Street Corridor (76)  -79.383200  43.654313
# 4               Downsview-Roding-CFB (26)  -79.513797  43.719824

# %%
# Filter out the assult cases in the TTC subway stations
criminal_data_subway = criminal_data_sorted[criminal_data_sorted['LOCATION_TYPE'].str.contains('Subway', case=False, na=False)]
criminal_data_subway
# Out:
#                       OCC_DATE       LOCATION_TYPE PREMISES_TYPE  \
# 0       2014/01/01 05:00:00+00  Ttc Subway Station       Transit
# 17      2013/12/31 05:00:00+00    Ttc Subway Train       Transit
# 43      2014/01/01 05:00:00+00  Ttc Subway Station       Transit
# 170     2014/01/05 05:00:00+00  Ttc Subway Station       Transit
# 203     2014/01/05 05:00:00+00  Ttc Subway Station       Transit
# ...                        ...                 ...           ...
# 191403  2023/09/25 04:00:00+00  Ttc Subway Station       Transit
# 191511  2023/09/26 04:00:00+00  Ttc Subway Station       Transit
# 191572  2023/09/27 04:00:00+00  Ttc Subway Station       Transit
# 191662  2023/09/27 04:00:00+00  Ttc Subway Station       Transit
# 191671  2023/09/29 04:00:00+00  Ttc Subway Station       Transit
#
#                       OFFENCE                       NEIGHBOURHOOD_140  \
# 0                     Assault                Rosedale-Moore Park (98)
# 17                    Assault                Bay Street Corridor (76)
# 43                    Assault                              Annex (95)
# 170     Assault Peace Officer              Church-Yonge Corridor (75)
# 203     Assault Peace Officer              Church-Yonge Corridor (75)
# ...                       ...                                     ...
# 191403                Assault               Downsview-Roding-CFB (26)
# 191511                Assault         Islington-City Centre West (14)
# 191572                Assault              Church-Yonge Corridor (75)
# 191662                Assault                Rosedale-Moore Park (98)
# 191671                Assault  Waterfront Communities-The Island (77)
#
#         LONG_WGS84  LAT_WGS84
# 0       -79.384206  43.670798
# 17      -79.386625  43.650847
# 43      -79.411785  43.666614
# 170     -79.380923  43.656323
# 203     -79.380923  43.656323
# ...            ...        ...
# 191403  -79.462768  43.750371
# 191511  -79.534550  43.638909
# 191572  -79.384592  43.664931
# 191662  -79.384206  43.670798
# 191671  -79.380577  43.646415
#
# [4890 rows x 7 columns]

# %%
# convert the occ_date column to datetime
criminal_data_subway["OCC_DATE"] = pd.to_datetime(criminal_data_subway['OCC_DATE'], utc = True)
criminal_data_subway
# Out:
# C:\Users\yuqih\AppData\Local\Temp\ipykernel_18404\322790936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   criminal_data_subway["OCC_DATE"] = pd.to_datetime(criminal_data_subway['OCC_DATE'], utc = True)
#                         OCC_DATE       LOCATION_TYPE PREMISES_TYPE  \
# 0      2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 17     2013-12-31 05:00:00+00:00    Ttc Subway Train       Transit
# 43     2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 170    2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 203    2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# ...                          ...                 ...           ...
# 191403 2023-09-25 04:00:00+00:00  Ttc Subway Station       Transit
# 191511 2023-09-26 04:00:00+00:00  Ttc Subway Station       Transit
# 191572 2023-09-27 04:00:00+00:00  Ttc Subway Station       Transit
# 191662 2023-09-27 04:00:00+00:00  Ttc Subway Station       Transit
# 191671 2023-09-29 04:00:00+00:00  Ttc Subway Station       Transit
#
#                       OFFENCE                       NEIGHBOURHOOD_140  \
# 0                     Assault                Rosedale-Moore Park (98)
# 17                    Assault                Bay Street Corridor (76)
# 43                    Assault                              Annex (95)
# 170     Assault Peace Officer              Church-Yonge Corridor (75)
# 203     Assault Peace Officer              Church-Yonge Corridor (75)
# ...                       ...                                     ...
# 191403                Assault               Downsview-Roding-CFB (26)
# 191511                Assault         Islington-City Centre West (14)
# 191572                Assault              Church-Yonge Corridor (75)
# 191662                Assault                Rosedale-Moore Park (98)
# 191671                Assault  Waterfront Communities-The Island (77)
#
#         LONG_WGS84  LAT_WGS84
# 0       -79.384206  43.670798
# 17      -79.386625  43.650847
# 43      -79.411785  43.666614
# 170     -79.380923  43.656323
# 203     -79.380923  43.656323
# ...            ...        ...
# 191403  -79.462768  43.750371
# 191511  -79.534550  43.638909
# 191572  -79.384592  43.664931
# 191662  -79.384206  43.670798
# 191671  -79.380577  43.646415
#
# [4890 rows x 7 columns]

# %%
# Set the date range to match the delay data
start_date = '2014/01/01 05:00:00+00'
end_date = '2023/09/30 05:00:00+00'

# Convert the start and end dates to datetime
start_date = pd.to_datetime(start_date)
end_date = pd.to_datetime(end_date)

# Filter out the 
criminal_data_subway = criminal_data_subway[(criminal_data_subway['OCC_DATE'] >= start_date) & (criminal_data_subway['OCC_DATE'] <= end_date)]
criminal_data_subway = criminal_data_subway.set_index('OCC_DATE')
criminal_data_subway.head()
# Out:
#                                 LOCATION_TYPE PREMISES_TYPE  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
#
#                                          OFFENCE  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00                Assault
# 2014-01-01 05:00:00+00:00                Assault
# 2014-01-05 05:00:00+00:00  Assault Peace Officer
# 2014-01-05 05:00:00+00:00  Assault Peace Officer
# 2014-01-05 05:00:00+00:00                Assault
#
#                                                   NEIGHBOURHOOD_140  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00                  Rosedale-Moore Park (98)
# 2014-01-01 05:00:00+00:00                                Annex (95)
# 2014-01-05 05:00:00+00:00                Church-Yonge Corridor (75)
# 2014-01-05 05:00:00+00:00                Church-Yonge Corridor (75)
# 2014-01-05 05:00:00+00:00  Dovercourt-Wallace Emerson-Junction (93)
#
#                            LONG_WGS84  LAT_WGS84
# OCC_DATE
# 2014-01-01 05:00:00+00:00  -79.384206  43.670798
# 2014-01-01 05:00:00+00:00  -79.411785  43.666614
# 2014-01-05 05:00:00+00:00  -79.380923  43.656323
# 2014-01-05 05:00:00+00:00  -79.380923  43.656323
# 2014-01-05 05:00:00+00:00  -79.435362  43.659878

# %%
filtered_df = criminal_data_subway[criminal_data_subway['LOCATION_TYPE'] != 'Ttc Subway Train']

filtered_df
# Out:
#                                 LOCATION_TYPE PREMISES_TYPE  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# ...                                       ...           ...
# 2023-09-25 04:00:00+00:00  Ttc Subway Station       Transit
# 2023-09-26 04:00:00+00:00  Ttc Subway Station       Transit
# 2023-09-27 04:00:00+00:00  Ttc Subway Station       Transit
# 2023-09-27 04:00:00+00:00  Ttc Subway Station       Transit
# 2023-09-29 04:00:00+00:00  Ttc Subway Station       Transit
#
#                                          OFFENCE  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00                Assault
# 2014-01-01 05:00:00+00:00                Assault
# 2014-01-05 05:00:00+00:00  Assault Peace Officer
# 2014-01-05 05:00:00+00:00  Assault Peace Officer
# 2014-01-05 05:00:00+00:00                Assault
# ...                                          ...
# 2023-09-25 04:00:00+00:00                Assault
# 2023-09-26 04:00:00+00:00                Assault
# 2023-09-27 04:00:00+00:00                Assault
# 2023-09-27 04:00:00+00:00                Assault
# 2023-09-29 04:00:00+00:00                Assault
#
#                                                   NEIGHBOURHOOD_140  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00                  Rosedale-Moore Park (98)
# 2014-01-01 05:00:00+00:00                                Annex (95)
# 2014-01-05 05:00:00+00:00                Church-Yonge Corridor (75)
# 2014-01-05 05:00:00+00:00                Church-Yonge Corridor (75)
# 2014-01-05 05:00:00+00:00  Dovercourt-Wallace Emerson-Junction (93)
# ...                                                             ...
# 2023-09-25 04:00:00+00:00                 Downsview-Roding-CFB (26)
# 2023-09-26 04:00:00+00:00           Islington-City Centre West (14)
# 2023-09-27 04:00:00+00:00                Church-Yonge Corridor (75)
# 2023-09-27 04:00:00+00:00                  Rosedale-Moore Park (98)
# 2023-09-29 04:00:00+00:00    Waterfront Communities-The Island (77)
#
#                            LONG_WGS84  LAT_WGS84
# OCC_DATE
# 2014-01-01 05:00:00+00:00  -79.384206  43.670798
# 2014-01-01 05:00:00+00:00  -79.411785  43.666614
# 2014-01-05 05:00:00+00:00  -79.380923  43.656323
# 2014-01-05 05:00:00+00:00  -79.380923  43.656323
# 2014-01-05 05:00:00+00:00  -79.435362  43.659878
# ...                               ...        ...
# 2023-09-25 04:00:00+00:00  -79.462768  43.750371
# 2023-09-26 04:00:00+00:00  -79.534550  43.638909
# 2023-09-27 04:00:00+00:00  -79.384592  43.664931
# 2023-09-27 04:00:00+00:00  -79.384206  43.670798
# 2023-09-29 04:00:00+00:00  -79.380577  43.646415
#
# [3898 rows x 6 columns]

# %%
first_occurrences = filtered_df.groupby('NEIGHBOURHOOD_140').first()[['LONG_WGS84', 'LAT_WGS84']]

for neighborhood in first_occurrences.index:
    longitude, latitude = first_occurrences.loc[neighborhood]
    filtered_df.loc[filtered_df['NEIGHBOURHOOD_140'] == neighborhood, 'LONG_WGS84'] = longitude
    filtered_df.loc[filtered_df['NEIGHBOURHOOD_140'] == neighborhood, 'LAT_WGS84'] = latitude
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py:1719: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
filtered_df.head(10)
# Out:
#                                 LOCATION_TYPE PREMISES_TYPE  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-07 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-07 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-07 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-07 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-07 05:00:00+00:00  Ttc Subway Station       Transit
#
#                                          OFFENCE  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00                Assault
# 2014-01-01 05:00:00+00:00                Assault
# 2014-01-05 05:00:00+00:00  Assault Peace Officer
# 2014-01-05 05:00:00+00:00  Assault Peace Officer
# 2014-01-05 05:00:00+00:00                Assault
# 2014-01-07 05:00:00+00:00    Assault With Weapon
# 2014-01-07 05:00:00+00:00    Assault With Weapon
# 2014-01-07 05:00:00+00:00    Assault With Weapon
# 2014-01-07 05:00:00+00:00    Assault With Weapon
# 2014-01-07 05:00:00+00:00    Assault With Weapon
#
#                                                   NEIGHBOURHOOD_140  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00                  Rosedale-Moore Park (98)
# 2014-01-01 05:00:00+00:00                                Annex (95)
# 2014-01-05 05:00:00+00:00                Church-Yonge Corridor (75)
# 2014-01-05 05:00:00+00:00                Church-Yonge Corridor (75)
# 2014-01-05 05:00:00+00:00  Dovercourt-Wallace Emerson-Junction (93)
# 2014-01-07 05:00:00+00:00                     Newtonbrook West (36)
# 2014-01-07 05:00:00+00:00                     Newtonbrook West (36)
# 2014-01-07 05:00:00+00:00                     Newtonbrook West (36)
# 2014-01-07 05:00:00+00:00                     Newtonbrook West (36)
# 2014-01-07 05:00:00+00:00                     Newtonbrook West (36)
#
#                            LONG_WGS84  LAT_WGS84
# OCC_DATE
# 2014-01-01 05:00:00+00:00  -79.384206  43.670798
# 2014-01-01 05:00:00+00:00  -79.411785  43.666614
# 2014-01-05 05:00:00+00:00  -79.380923  43.656323
# 2014-01-05 05:00:00+00:00  -79.380923  43.656323
# 2014-01-05 05:00:00+00:00  -79.435362  43.659878
# 2014-01-07 05:00:00+00:00  -79.415998  43.781631
# 2014-01-07 05:00:00+00:00  -79.415998  43.781631
# 2014-01-07 05:00:00+00:00  -79.415998  43.781631
# 2014-01-07 05:00:00+00:00  -79.415998  43.781631
# 2014-01-07 05:00:00+00:00  -79.415998  43.781631

# %%
counts = filtered_df['NEIGHBOURHOOD_140'].value_counts()


# Converting the Series to a DataFrame
station_counts_df = counts.reset_index()
station_counts_df.columns = ['Station', 'Count']



# This will print the count of each unique value in the NEIGHBOURHOOD_140 column
station_counts_df.head(50)
# Out:
#                                      Station  Count
# 0                 Church-Yonge Corridor (75)    531
# 1                                 Annex (95)    432
# 2                   Rosedale-Moore Park (98)    276
# 3                         Kennedy Park (124)    205
# 4                              Danforth (66)    167
# 5                       Yonge-Eglinton (100)    166
# 6                      Newtonbrook West (36)    157
# 7   Dovercourt-Wallace Emerson-Junction (93)    153
# 8     Waterfront Communities-The Island (77)    142
# 9            Islington-City Centre West (14)    139
# 10                      High Park North (88)    139
# 11                    East End-Danforth (62)    119
# 12                 Clairlea-Birchmount (120)    109
# 13             Playter Estates-Danforth (67)    109
# 14                  Bay Street Corridor (76)    109
# 15                            Oakridge (121)    104
# 16                     Lansing-Westgate (38)     74
# 17                 Downsview-Roding-CFB (26)     64
# 18                         Clanton Park (33)     57
# 19                   Yorkdale-Glen Park (31)     57
# 20                 Lawrence Park North (105)     51
# 21                      Willowdale West (37)     45
# 22                            Casa Loma (96)     44
# 23                  North St.James Town (74)     43
# 24                   Don Valley Village (47)     39
# 25              York University Heights (27)     39
# 26                                       NSA     39
# 27                       Kingsway South (15)     34
# 28                   Forest Hill North (102)     33
# 29                             Bendale (127)     28
# 30         Runnymede-Bloor West Village (89)     24
# 31    Bridle Path-Sunnybrook-York Mills (41)     23
# 32                 St.Andrew-Windfields (40)     17
# 33                     Newtonbrook East (50)     15
# 34                      Bayview Village (52)     15
# 35                      Willowdale East (51)     13
# 36                 Kensington-Chinatown (78)     13
# 37                      North Riverdale (68)      9
# 38                       Yonge-St.Clair (97)      7
# 39                         Dorset Park (126)      6
# 40                             Ionview (125)      4
# 41                          Blake-Jones (69)      4
# 42                   Rockcliffe-Smythe (111)      3
# 43                           University (79)      3
# 44                 Mount Pleasant West (104)      3
# 45                  Englemount-Lawrence (32)      2
# 46                      South Riverdale (70)      2
# 47                    High Park-Swansea (87)      2
# 48                    Woodbine Corridor (64)      2
# 49                          The Beaches (63)      2

# %%
subset_df1 = filtered_df[['NEIGHBOURHOOD_140', 'LONG_WGS84', 'LAT_WGS84']]

# Rename the 'Station' column in df2 to 'NEIGHBOURHOOD_140' to match df1
station_counts_df.rename(columns={'Station': 'NEIGHBOURHOOD_140'}, inplace=True)

# Merge the DataFrames on the NEIGHBOURHOOD_140 column
merged_df = pd.merge(station_counts_df, subset_df1, on='NEIGHBOURHOOD_140', how='left')
merged_df = merged_df.drop_duplicates(subset='NEIGHBOURHOOD_140')
# Select the top 20 rows
merged_df = merged_df.head(20)

merged_df.head(15)
# Out:
#                              NEIGHBOURHOOD_140  Count  LONG_WGS84  LAT_WGS84
# 0                   Church-Yonge Corridor (75)    531  -79.380923  43.656323
# 531                                 Annex (95)    432  -79.411785  43.666614
# 963                   Rosedale-Moore Park (98)    276  -79.384206  43.670798
# 1239                        Kennedy Park (124)    205  -79.264551  43.732765
# 1444                             Danforth (66)    167  -79.345152  43.679673
# 1611                      Yonge-Eglinton (100)    166  -79.397849  43.704345
# 1777                     Newtonbrook West (36)    157  -79.415998  43.781631
# 1934  Dovercourt-Wallace Emerson-Junction (93)    153  -79.435362  43.659878
# 2087    Waterfront Communities-The Island (77)    142  -79.379131  43.645981
# 2229           Islington-City Centre West (14)    139  -79.534550  43.638909
# 2368                      High Park North (88)    139  -79.460028  43.655340
# 2507                    East End-Danforth (62)    119  -79.300984  43.689426
# 2626                 Clairlea-Birchmount (120)    109  -79.281000  43.712040
# 2735             Playter Estates-Danforth (67)    109  -79.358099  43.676764
# 2844                  Bay Street Corridor (76)    109  -79.390491  43.659853

# %%
import folium
from folium.plugins import MarkerCluster
import branca.colormap as cm

m = folium.Map(location=[43.656323, -79.380923], zoom_start=12,tiles='CartoDB positron',
               width='80%', height='200%')

# Create a color scale
color_scale = cm.linear.YlOrRd_09.scale(min(merged_df['Count']), max(merged_df['Count']))

# Add points
for _, row in merged_df.iterrows():
    folium.CircleMarker(location=[row['LAT_WGS84'], row['LONG_WGS84']],
                        radius=10,
                        color=color_scale(row['Count']),
                        fill=True,
                        fill_color=color_scale(row['Count']),
                        fill_opacity=5).add_to(m)

# Add color scale to map
color_scale.add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b45ac6c132af8edd847ae9b42374edbf {
#                     position: relative;
#                     width: 80.0%;
#                     height: 200.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b45ac6c132af8edd847ae9b42374edbf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b45ac6c132af8edd847ae9b42374edbf = L.map(
#                 &quot;map_b45ac6c132af8edd847ae9b42374edbf&quot;,
#                 {
#                     center: [43.656323, -79.380923],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92333bf34440dbf8120f45a22d0134cd = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_92333bf34440dbf8120f45a22d0134cd.addTo(map_b45ac6c132af8edd847ae9b42374edbf);
#
#             var circle_marker_d18316fbd477dc6fb377e90eba89f2f9 = L.circleMarker(
#                 [43.6563225842995, -79.3809227673582],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#800026ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#800026ff&quot;, &quot;fillOpacity&quot;: 5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b45ac6c132af8edd847ae9b42374edbf);
#
#
#             var circle_marker_e6dddb4d229dc0e73f6c041330f0db3a = L.circleMarker(
#                 [43.6666143715903, -79.4117848023346],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d7111fff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d7111fff&quot;, &quot;fillOpacity&quot;: 5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b45ac6c132af8edd847ae9b42374edbf);
#
#
#             var circle_marker_998dce605a2f09a8aaebc29802b85866 = L.circleMarker(
#                 [43.6707982509655, -79.3842059245105],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fe9841ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fe9841ff&quot;, &quot;fillOpacity&quot;: 5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b45ac6c132af8edd847ae9b42374edbf);
#
#
#             var circle_marker_442f96796f68ee4d77a292c27e00908e = L.circleMarker(
#                 [43.7327646468606, -79.2645508958054],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fec661ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fec661ff&quot;, &quot;fillOpacity&quot;: 5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b45ac6c132af8edd847ae9b42374edbf);
#
#
#             var circle_marker_734c26d21213687d02c399d9f9eb70df = L.circleMarker(
#                 [43.6796730723028, -79.3451524009597],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffdc7cff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffdc7cff&quot;, &quot;fillOpacity&quot;: 5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b45ac6c132af8edd847ae9b42374edbf);
#
#
#             var circle_marker_27eef98c504832c5bfa4e9428f2a1cb7 = L.circleMarker(
#                 [43.7043446485815, -79.3978488203008],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffdd7dff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fil

# %%
#find the delay with Disorderly Patron

# %%
import geopandas as gpd

# Load a shapefile
gdf = gpd.read_file('subway_stations.shp')

# Display the first few rows of the GeoDataFrame
gdf.head()
# Out:
#       STATION            LINE PLATFORM_L  AVG_PASSEN LINE2 PLATFORM_1  \
# 0     Kipling  Bloor-Danforth          1       53640  None       None
# 1   Islington  Bloor-Danforth          1       43090  None       None
# 2  Royal York  Bloor-Danforth          2       19440  None       None
# 3    Old Mill  Bloor-Danforth          2        5780  None       None
# 4        Jane  Bloor-Danforth          2       16730  None       None
#
#   SUBWAY_TRA               ADDRESS  Opened                        geometry
# 0      False  5247 Dundas St. West    1980  POINT (618101.613 4832636.300)
# 1      False   3286 Bloor St. West    1968  POINT (618990.613 4833544.113)
# 2      False   3012 Bloor St. West    1968  POINT (620056.496 4833882.764)
# 3      False   2672 Bloor St. West    1968  POINT (621361.678 4834111.901)
# 4      False   2440 Bloor St. West    1968  POINT (622220.664 4834091.381)

# %%
selected_df = gdf[['STATION', 'geometry']]
selected_df.head()
# Out:
#       STATION                        geometry
# 0     Kipling  POINT (618101.613 4832636.300)
# 1   Islington  POINT (618990.613 4833544.113)
# 2  Royal York  POINT (620056.496 4833882.764)
# 3    Old Mill  POINT (621361.678 4834111.901)
# 4        Jane  POINT (622220.664 4834091.381)

# %%
selected_df['STATION'] = selected_df['STATION'].str.upper()
selected_df.head(25)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#          STATION                        geometry
# 0        KIPLING  POINT (618101.613 4832636.300)
# 1      ISLINGTON  POINT (618990.613 4833544.113)
# 2     ROYAL YORK  POINT (620056.496 4833882.764)
# 3       OLD MILL  POINT (621361.678 4834111.901)
# 4           JANE  POINT (622220.664 4834091.381)
# 5      RUNNYMEDE  POINT (622874.508 4834305.389)
# 6      HIGH PARK  POINT (623684.881 4834584.911)
# 7          KEELE  POINT (624191.616 4834764.330)
# 8    DUNDAS WEST  POINT (624793.207 4834950.950)
# 9      LANSDOWNE  POINT (625578.442 4835178.398)
# 10      DUFFERIN  POINT (626149.245 4835327.525)
# 11     OSSINGTON  POINT (626913.372 4835583.067)
# 12      CHRISTIE  POINT (627514.339 4835782.256)
# 13      BATHURST  POINT (628086.304 4835966.589)
# 14       SPADINA  POINT (628673.537 4836158.690)
# 15    ST. GEORGE  POINT (629030.694 4836275.417)
# 16           BAY  POINT (629802.318 4836509.401)
# 17   BLOOR-YONGE  POINT (630136.965 4836575.675)
# 18    SHERBOURNE  POINT (630873.934 4836757.897)
# 19  CASTLE FRANK  POINT (631521.278 4836950.424)
# 20     BROADVIEW  POINT (632306.357 4837276.516)
# 21       CHESTER  POINT (632820.046 4837463.555)
# 22          PAPE  POINT (633395.729 4837636.901)
# 23      DONLANDS  POINT (633978.101 4837809.557)
# 24     GREENWOOD  POINT (634580.840 4837995.900)

# %%
selected_df.to_csv('geometry.csv', index=False)

# %%
# Read the CSV into a DataFrame
delay = pd.read_csv('TTC_Real_Delay_2014_to_2023.csv')
delay.head()
# Out:
#               Datetime     Day                Station   Code  Min Delay  \
# 0  2018-01-01 00:29:00  Monday  SHEPPARD WEST STATION  MUATC         10
# 1  2018-01-01 01:39:00  Monday         MUSEUM STATION    MUO          6
# 2  2018-01-01 02:09:00  Monday        KIPLING STATION  MUSAN          3
# 3  2018-01-01 02:42:00  Monday        COLLEGE STATION   SUDP          7
# 4  2018-01-01 03:06:00  Monday         WARDEN STATION    MUI          3
#
#    Min Gap Bound Line  Vehicle  \
# 0       15     N  YUS     5986
# 1       11     S  YUS     5781
# 2        7     E   BD     5261
# 3       12     N  YUS     5696
# 4        7     E   BD     5257
#
#                                    Code description  time_interval
# 0                                       ATC Project  00:00 - 01:00
# 1                               Miscellaneous Other  01:00 - 02:00
# 2                                Unsanitary Vehicle  02:00 - 03:00
# 3                                 Disorderly Patron  02:00 - 03:00
# 4  Injured or ill Customer (On Train) - Transported  03:00 - 04:00

# %%
filtered_code = delay[delay['Code'] == 'SUDP']

filtered_code.head()
# Out:
#                Datetime        Day               Station  Code  Min Delay  \
# 3   2018-01-01 02:42:00     Monday       COLLEGE STATION  SUDP          7
# 15  2018-01-01 15:36:00     Monday    SHERBOURNE STATION  SUDP          5
# 39  2018-01-02 09:18:00    Tuesday    FINCH WEST STATION  SUDP          3
# 41  2018-01-02 11:28:00    Tuesday      OLD MILL STATION  SUDP         13
# 66  2018-01-03 12:56:00  Wednesday  ST GEORGE BD STATION  SUDP          7
#
#     Min Gap Bound Line  Vehicle   Code description  time_interval
# 3        12     N  YUS     5696  Disorderly Patron  02:00 - 03:00
# 15       10     E   BD     5269  Disorderly Patron  15:00 - 16:00
# 39        7     S  YUS     6096  Disorderly Patron  09:00 - 10:00
# 41       16     E   BD     5358  Disorderly Patron  11:00 - 12:00
# 66       10     E   BD     5265  Disorderly Patron  12:00 - 13:00

# %%
delay_stn = filtered_code['Station'].value_counts()


# Converting the Series to a DataFrame
delay_stn = delay_stn.reset_index()
delay_stn.columns = ['Station', 'Count']

delay_stn.head(25)
# Out:
#                   Station  Count
# 0           BLOOR STATION    370
# 1        EGLINTON STATION    229
# 2      KENNEDY BD STATION    187
# 3        YONGE BD STATION    176
# 4         COXWELL STATION    164
# 5   ST GEORGE YUS STATION    161
# 6         KIPLING STATION    156
# 7    ST GEORGE BD STATION    150
# 8      DAVISVILLE STATION    150
# 9           FINCH STATION    139
# 10       LAWRENCE STATION    136
# 11      BROADVIEW STATION    134
# 12      WELLESLEY STATION    133
# 13        COLLEGE STATION    132
# 14         DUNDAS STATION    126
# 15  ST CLAIR WEST STATION    126
# 16       ST CLAIR STATION    123
# 17   CASTLE FRANK STATION    112
# 18          QUEEN STATION    110
# 19     SPADINA BD STATION    110
# 20         WARDEN STATION    107
# 21     SUMMERHILL STATION    103
# 22      OSSINGTON STATION    101
# 23       CHRISTIE STATION    100
# 24          UNION STATION    100

# %%
delay_stn['Station'] = delay_stn['Station'].str.replace(" STATION", "", regex=False)

# %%
merged_df_delay = pd.merge(delay_stn, selected_df, left_on='Station', right_on='STATION', how='left')

merged_df_delay = merged_df_delay.head(65)
merged_df_delay.at[0, 'geometry'] = selected_df.at[17, 'geometry']
merged_df_delay.at[2, 'geometry'] = selected_df.at[30, 'geometry']
merged_df_delay.at[3, 'geometry'] = selected_df.at[17, 'geometry']
merged_df_delay.at[5, 'geometry'] = selected_df.at[15, 'geometry']
merged_df_delay.at[7, 'geometry'] = selected_df.at[15, 'geometry']
merged_df_delay.at[16, 'geometry'] = selected_df.at[44, 'geometry']
merged_df_delay.at[19, 'geometry'] = selected_df.at[14, 'geometry']
merged_df_delay.at[26, 'geometry'] = selected_df.at[49, 'geometry']
merged_df_delay.at[30, 'geometry'] = selected_df.at[14, 'geometry']
merged_df_delay.at[35, 'geometry'] = selected_df.at[49, 'geometry']
merged_df_delay.at[50, 'geometry'] = selected_df.at[50, 'geometry']
merged_df_delay = merged_df_delay.dropna(subset=['geometry'])

merged_df_delay.head()
# Out:
#       Station  Count   STATION                        geometry
# 0       BLOOR    370       NaN  POINT (630136.965 4836575.675)
# 1    EGLINTON    229  EGLINTON  POINT (629021.977 4840533.356)
# 2  KENNEDY BD    187       NaN  POINT (639834.126 4843622.665)
# 3    YONGE BD    176       NaN  POINT (630136.965 4836575.675)
# 4     COXWELL    164   COXWELL  POINT (635157.330 4838173.966)

# %%
delay_df = merged_df_delay[['geometry','Count']]
delay_df
# Out:
#                           geometry  Count
# 0   POINT (630136.965 4836575.675)    370
# 1   POINT (629021.977 4840533.356)    229
# 2   POINT (639834.126 4843622.665)    187
# 3   POINT (630136.965 4836575.675)    176
# 4   POINT (635157.330 4838173.966)    164
# ..                             ...    ...
# 59  POINT (622220.664 4834091.381)     47
# 60  POINT (625014.722 4842562.269)     44
# 61  POINT (633087.137 4848247.384)     43
# 62  POINT (621361.678 4834111.901)     43
# 64  POINT (622874.508 4834305.389)     39
#
# [61 rows x 2 columns]

# %%
delay_df['geometry']
# Out:
# 0     POINT (630136.965 4836575.675)
# 1     POINT (629021.977 4840533.356)
# 2     POINT (639834.126 4843622.665)
# 3     POINT (630136.965 4836575.675)
# 4     POINT (635157.330 4838173.966)
#                    ...
# 59    POINT (622220.664 4834091.381)
# 60    POINT (625014.722 4842562.269)
# 61    POINT (633087.137 4848247.384)
# 62    POINT (621361.678 4834111.901)
# 64    POINT (622874.508 4834305.389)
# Name: geometry, Length: 61, dtype: geometry

# %%
import pandas as pd
from pyproj import Proj, Transformer
from shapely.geometry import Point

utm_zone = 17
is_south = False

# Create a Transformer object for UTM to WGS84 coordinate transformation
transformer = Transformer.from_proj(
    Proj(proj='utm', zone=utm_zone, ellps='WGS84', south=is_south),
    Proj(proj='latlong', datum='WGS84')
)

# Function to convert UTM to Lat/Lon
def utm_to_latlon(point):
    if point and isinstance(point, Point):
        lon, lat = transformer.transform(point.x, point.y)
        return lat, lon
    else:
        return None, None

# Apply the function to the 'geometry' column
delay_df[['Latitude', 'Longitude']] = delay_df['geometry'].apply(utm_to_latlon).apply(pd.Series)

# Display the DataFrame
print(delay_df)
# Out:
#                           geometry  Count   Latitude  Longitude
# 0   POINT (630136.965 4836575.675)    370  43.670793 -79.385730
# 1   POINT (629021.977 4840533.356)    229  43.706609 -79.398608
# 2   POINT (639834.126 4843622.665)    187  43.732453 -79.263665
# 3   POINT (630136.965 4836575.675)    176  43.670793 -79.385730
# 4   POINT (635157.330 4838173.966)    164  43.684282 -79.323080
# ..                             ...    ...        ...        ...
# 59  POINT (622220.664 4834091.381)     47  43.649777 -79.484455
# 60  POINT (625014.722 4842562.269)     44  43.725556 -79.447855
# 61  POINT (633087.137 4848247.384)     43  43.775318 -79.346262
# 62  POINT (621361.678 4834111.901)     43  43.650102 -79.495098
# 64  POINT (622874.508 4834305.389)     39  43.651595 -79.476301
#
# [61 rows x 4 columns]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py:3188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
import folium
import branca.colormap as cm

# Assuming df is your DataFrame with 'lat', 'lon', and 'count' columns

# Create a base map
y = folium.Map(location=[43.656323, -79.380923], zoom_start=12, tiles='CartoDB positron')

# Create a color scale
min_count = delay_df['Count'].min()
max_count = delay_df['Count'].max()
color_scale = cm.linear.Blues_09.scale(min_count, max_count)

# Add points
for _, row in delay_df.iterrows():
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=8,
        color=color_scale(row['Count']),
        fill=True,
        fill_color=color_scale(row['Count']),
        fill_opacity=0.7
    ).add_to(y)

# Add color scale to map
color_scale.add_to(y)

# Display the map
y
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ff0941202b912e3449cb6453140cee1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ff0941202b912e3449cb6453140cee1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ff0941202b912e3449cb6453140cee1 = L.map(
#                 &quot;map_4ff0941202b912e3449cb6453140cee1&quot;,
#                 {
#                     center: [43.656323, -79.380923],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88a7bde74ed845ddd257c3d5edb72854 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_88a7bde74ed845ddd257c3d5edb72854.addTo(map_4ff0941202b912e3449cb6453140cee1);
#
#             var circle_marker_41dd8c21b0951160d47b4bb3b189e6e2 = L.circleMarker(
#                 [43.67079307750765, -79.38572988220892],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#08306bff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#08306bff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4ff0941202b912e3449cb6453140cee1);
#
#
#             var circle_marker_f64ca810a7eaa825091615935c866079 = L.circleMarker(
#                 [43.70660856274189, -79.3986076294025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#539ecdff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#539ecdff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4ff0941202b912e3449cb6453140cee1);
#
#
#             var circle_marker_2297d185b08a9c4fb293e3fe5d9a2e68 = L.circleMarker(
#                 [43.73245325444283, -79.2636650509306],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#81badbff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#81badbff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4ff0941202b912e3449cb6453140cee1);
#
#
#             var circle_marker_8a6281537c69c035a968895fe6f5dba7 = L.circleMarker(
#                 [43.67079307750765, -79.38572988220892],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8ec2deff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8ec2deff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4ff0941202b912e3449cb6453140cee1);
#
#
#             var circle_marker_b5f7ee29d1898edf311039a708684b03 = L.circleMarker(
#                 [43.68428170572595, -79.32308043145007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#9dcae1ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#9dcae1ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4ff0941202b912e3449cb6453140cee1);
#
#
#             var circle_marker_f0004265a371166482021d78b9a4f3a0 = L.circleMarker(
#                 [43.66828353935196, -79.39951903913077],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#a0cbe2ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;:
