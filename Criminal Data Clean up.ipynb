# %% [markdown]
# # Toronto Criminal Data Record

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
import folium
import branca.colormap as cm

# %matplotlib inline
plt.style.use('ggplot')
sns.set_context("notebook")
import warnings
warnings.filterwarnings("ignore")
# Out:
# c:\Users\yuqih\AppData\Local\Programs\Python\Python39\lib\site-packages\geopandas\_compat.py:123: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ## 1. Read the file

# %%
# Read the CSV into a DataFrame
criminal_data_raw = pd.read_csv('Criminal Data and Disorderly Patrons Data\Assault_Open_Data.csv')
criminal_data_raw.head()
# Out:
#               X             Y  OBJECTID EVENT_UNIQUE_ID  \
# 0 -8.837009e+06  5.414638e+06         1  GO-20141265238
# 1 -8.832733e+06  5.419701e+06         2  GO-20141259834
# 2 -8.836444e+06  5.410819e+06         3  GO-20141262027
# 3 -8.836897e+06  5.412101e+06         4  GO-20141259951
# 4 -8.851435e+06  5.422186e+06         5  GO-20141261561
#
#               REPORT_DATE                OCC_DATE  REPORT_YEAR REPORT_MONTH  \
# 0  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00         2014      January
# 1  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00         2014      January
# 2  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00         2014      January
# 3  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00         2014      January
# 4  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00         2014      January
#
#    REPORT_DAY  REPORT_DOY  ... UCR_CODE  UCR_EXT                OFFENCE  \
# 0           1           1  ...     1430      100                Assault
# 1           1           1  ...     1420      100    Assault With Weapon
# 2           1           1  ...     1430      100                Assault
# 3           1           1  ...     1460      100  Assault Peace Officer
# 4           1           1  ...     1420      100    Assault With Weapon
#
#   MCI_CATEGORY  HOOD_158                      NEIGHBOURHOOD_158 HOOD_140  \
# 0      Assault        98                    Rosedale-Moore Park       98
# 1      Assault        55                       Thorncliffe Park       55
# 2      Assault       166  St Lawrence-East Bayfront-The Islands       77
# 3      Assault       170                     Yonge-Bay Corridor       76
# 4      Assault       154               Oakdale-Beverley Heights       26
#
#                         NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 0                Rosedale-Moore Park (98) -79.384206  43.670798
# 1                   Thorncliffe Park (55) -79.345795  43.703684
# 2  Waterfront Communities-The Island (77) -79.379131  43.645981
# 3                Bay Street Corridor (76) -79.383200  43.654313
# 4               Downsview-Roding-CFB (26) -79.513797  43.719824
#
# [5 rows x 31 columns]

# %%
#create a new data frame contains the useful columns below
#OCC_DATE
#LOCATION_TYPE
#PREMISES_TYPE
#OFFENCE
#NEIGHBOURHOOD_140
#LONG_WGS84
#LAT_WGS84


criminal_data_sorted = criminal_data_raw[['OCC_DATE','LOCATION_TYPE','PREMISES_TYPE',
                                          'OFFENCE','NEIGHBOURHOOD_140','LONG_WGS84','LAT_WGS84']]

criminal_data_sorted.head()
# Out:
#                  OCC_DATE                                      LOCATION_TYPE  \
# 0  2014/01/01 05:00:00+00                                 Ttc Subway Station
# 1  2014/01/01 05:00:00+00                                   Bar / Restaurant
# 2  2014/01/01 05:00:00+00  Streets, Roads, Highways (Bicycle Path, Privat...
# 3  2014/01/01 05:00:00+00  Streets, Roads, Highways (Bicycle Path, Privat...
# 4  2014/01/01 05:00:00+00  Commercial Dwelling Unit (Hotel, Motel, B & B,...
#
#   PREMISES_TYPE                OFFENCE  \
# 0       Transit                Assault
# 1    Commercial    Assault With Weapon
# 2       Outside                Assault
# 3       Outside  Assault Peace Officer
# 4    Commercial    Assault With Weapon
#
#                         NEIGHBOURHOOD_140  LONG_WGS84  LAT_WGS84
# 0                Rosedale-Moore Park (98)  -79.384206  43.670798
# 1                   Thorncliffe Park (55)  -79.345795  43.703684
# 2  Waterfront Communities-The Island (77)  -79.379131  43.645981
# 3                Bay Street Corridor (76)  -79.383200  43.654313
# 4               Downsview-Roding-CFB (26)  -79.513797  43.719824

# %%
# Filter out data related to the subway stations
criminal_data_subway = criminal_data_sorted[criminal_data_sorted['LOCATION_TYPE'].str.contains('Subway', case=False, na=False)]
criminal_data_subway.head()
# Out:
#                    OCC_DATE       LOCATION_TYPE PREMISES_TYPE  \
# 0    2014/01/01 05:00:00+00  Ttc Subway Station       Transit
# 17   2013/12/31 05:00:00+00    Ttc Subway Train       Transit
# 43   2014/01/01 05:00:00+00  Ttc Subway Station       Transit
# 170  2014/01/05 05:00:00+00  Ttc Subway Station       Transit
# 203  2014/01/05 05:00:00+00  Ttc Subway Station       Transit
#
#                    OFFENCE           NEIGHBOURHOOD_140  LONG_WGS84  LAT_WGS84
# 0                  Assault    Rosedale-Moore Park (98)  -79.384206  43.670798
# 17                 Assault    Bay Street Corridor (76)  -79.386625  43.650847
# 43                 Assault                  Annex (95)  -79.411785  43.666614
# 170  Assault Peace Officer  Church-Yonge Corridor (75)  -79.380923  43.656323
# 203  Assault Peace Officer  Church-Yonge Corridor (75)  -79.380923  43.656323

# %%
#convert the occ_date column to datetime
criminal_data_subway['OCC_DATE'] = pd.to_datetime(criminal_data_subway['OCC_DATE'])

# %%
# make sure the occ date range match with the delay time
start_date = '2014/01/01 05:00:00+00'
end_date = '2023/09/30 05:00:00+00'

# Convert the start and end dates to datetime
start_date = pd.to_datetime(start_date)
end_date = pd.to_datetime(end_date)

# Filter out the date between the start date and the end date
criminal_data_subway = criminal_data_subway[(criminal_data_subway['OCC_DATE'] >= start_date) & (criminal_data_subway['OCC_DATE'] <= end_date)]
# Set the OOC_DATE as the index
criminal_data_subway = criminal_data_subway.set_index('OCC_DATE')
criminal_data_subway.head()
# Out:
#                                 LOCATION_TYPE PREMISES_TYPE  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
#
#                                          OFFENCE  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00                Assault
# 2014-01-01 05:00:00+00:00                Assault
# 2014-01-05 05:00:00+00:00  Assault Peace Officer
# 2014-01-05 05:00:00+00:00  Assault Peace Officer
# 2014-01-05 05:00:00+00:00                Assault
#
#                                                   NEIGHBOURHOOD_140  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00                  Rosedale-Moore Park (98)
# 2014-01-01 05:00:00+00:00                                Annex (95)
# 2014-01-05 05:00:00+00:00                Church-Yonge Corridor (75)
# 2014-01-05 05:00:00+00:00                Church-Yonge Corridor (75)
# 2014-01-05 05:00:00+00:00  Dovercourt-Wallace Emerson-Junction (93)
#
#                            LONG_WGS84  LAT_WGS84
# OCC_DATE
# 2014-01-01 05:00:00+00:00  -79.384206  43.670798
# 2014-01-01 05:00:00+00:00  -79.411785  43.666614
# 2014-01-05 05:00:00+00:00  -79.380923  43.656323
# 2014-01-05 05:00:00+00:00  -79.380923  43.656323
# 2014-01-05 05:00:00+00:00  -79.435362  43.659878

# %%
# Filter out the location at TTC Subway Trains
filtered_df = criminal_data_subway[criminal_data_subway['LOCATION_TYPE'] != 'Ttc Subway Train']
filtered_df["LOCATION_TYPE"].unique()
# Out:
# array(['Ttc Subway Station', 'Ttc Subway Tunnel / Outdoor Tracks'],
#       dtype=object)

# %%
# Group the data by the neighbourhood
first_occurrences = filtered_df.groupby('NEIGHBOURHOOD_140').first()[['LONG_WGS84', 'LAT_WGS84']]

for neighborhood in first_occurrences.index:
    longitude, latitude = first_occurrences.loc[neighborhood]
    filtered_df.loc[filtered_df['NEIGHBOURHOOD_140'] == neighborhood, 'LONG_WGS84'] = longitude
    filtered_df.loc[filtered_df['NEIGHBOURHOOD_140'] == neighborhood, 'LAT_WGS84'] = latitude

filtered_df.head(10)
# Out:
#                                 LOCATION_TYPE PREMISES_TYPE  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-01 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-05 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-07 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-07 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-07 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-07 05:00:00+00:00  Ttc Subway Station       Transit
# 2014-01-07 05:00:00+00:00  Ttc Subway Station       Transit
#
#                                          OFFENCE  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00                Assault
# 2014-01-01 05:00:00+00:00                Assault
# 2014-01-05 05:00:00+00:00  Assault Peace Officer
# 2014-01-05 05:00:00+00:00  Assault Peace Officer
# 2014-01-05 05:00:00+00:00                Assault
# 2014-01-07 05:00:00+00:00    Assault With Weapon
# 2014-01-07 05:00:00+00:00    Assault With Weapon
# 2014-01-07 05:00:00+00:00    Assault With Weapon
# 2014-01-07 05:00:00+00:00    Assault With Weapon
# 2014-01-07 05:00:00+00:00    Assault With Weapon
#
#                                                   NEIGHBOURHOOD_140  \
# OCC_DATE
# 2014-01-01 05:00:00+00:00                  Rosedale-Moore Park (98)
# 2014-01-01 05:00:00+00:00                                Annex (95)
# 2014-01-05 05:00:00+00:00                Church-Yonge Corridor (75)
# 2014-01-05 05:00:00+00:00                Church-Yonge Corridor (75)
# 2014-01-05 05:00:00+00:00  Dovercourt-Wallace Emerson-Junction (93)
# 2014-01-07 05:00:00+00:00                     Newtonbrook West (36)
# 2014-01-07 05:00:00+00:00                     Newtonbrook West (36)
# 2014-01-07 05:00:00+00:00                     Newtonbrook West (36)
# 2014-01-07 05:00:00+00:00                     Newtonbrook West (36)
# 2014-01-07 05:00:00+00:00                     Newtonbrook West (36)
#
#                            LONG_WGS84  LAT_WGS84
# OCC_DATE
# 2014-01-01 05:00:00+00:00  -79.384206  43.670798
# 2014-01-01 05:00:00+00:00  -79.411785  43.666614
# 2014-01-05 05:00:00+00:00  -79.380923  43.656323
# 2014-01-05 05:00:00+00:00  -79.380923  43.656323
# 2014-01-05 05:00:00+00:00  -79.435362  43.659878
# 2014-01-07 05:00:00+00:00  -79.415998  43.781631
# 2014-01-07 05:00:00+00:00  -79.415998  43.781631
# 2014-01-07 05:00:00+00:00  -79.415998  43.781631
# 2014-01-07 05:00:00+00:00  -79.415998  43.781631
# 2014-01-07 05:00:00+00:00  -79.415998  43.781631

# %%
# Count how many occurance at each neightbourhood
counts = filtered_df['NEIGHBOURHOOD_140'].value_counts()

# Converting the Series to a DataFrame
station_counts_df = counts.reset_index()
station_counts_df.columns = ['Station', 'Count']

# This will print the count of each unique value in the NEIGHBOURHOOD_140 column
station_counts_df.head()
# Out:
#                       Station  Count
# 0  Church-Yonge Corridor (75)    531
# 1                  Annex (95)    432
# 2    Rosedale-Moore Park (98)    276
# 3          Kennedy Park (124)    205
# 4               Danforth (66)    167

# %%
# Keep neighbourhood, longitude and latitude of the original dataframe
subset_df1 = filtered_df[['NEIGHBOURHOOD_140', 'LONG_WGS84', 'LAT_WGS84']]

# Rename the 'Station' column in df2 to 'NEIGHBOURHOOD_140' to match df1
station_counts_df.rename(columns={'Station': 'NEIGHBOURHOOD_140'}, inplace=True)

# Merge the DataFrames on the NEIGHBOURHOOD_140 column
merged_df = pd.merge(station_counts_df, subset_df1, on='NEIGHBOURHOOD_140', how='left')
merged_df = merged_df.drop_duplicates(subset='NEIGHBOURHOOD_140')
# Select the top 20 rows
merged_df = merged_df.head(20)

merged_df.head(15)
# Out:
#                              NEIGHBOURHOOD_140  Count  LONG_WGS84  LAT_WGS84
# 0                   Church-Yonge Corridor (75)    531  -79.380923  43.656323
# 531                                 Annex (95)    432  -79.411785  43.666614
# 963                   Rosedale-Moore Park (98)    276  -79.384206  43.670798
# 1239                        Kennedy Park (124)    205  -79.264551  43.732765
# 1444                             Danforth (66)    167  -79.345152  43.679673
# 1611                      Yonge-Eglinton (100)    166  -79.397849  43.704345
# 1777                     Newtonbrook West (36)    157  -79.415998  43.781631
# 1934  Dovercourt-Wallace Emerson-Junction (93)    153  -79.435362  43.659878
# 2087    Waterfront Communities-The Island (77)    142  -79.379131  43.645981
# 2229                      High Park North (88)    139  -79.460028  43.655340
# 2368           Islington-City Centre West (14)    139  -79.534550  43.638909
# 2507                    East End-Danforth (62)    119  -79.300984  43.689426
# 2626                  Bay Street Corridor (76)    109  -79.390491  43.659853
# 2735             Playter Estates-Danforth (67)    109  -79.358099  43.676764
# 2844                 Clairlea-Birchmount (120)    109  -79.281000  43.712040

# %% [markdown]
# ## 2. Plot the map

# %%
# Set up the map
m = folium.Map(location=[43.656323, -79.380923], zoom_start=12, tiles='CartoDB positron', width='80%', height='100%')

# Create a color scale
color_scale = cm.linear.YlOrRd_09.scale(min(merged_df['Count']), max(merged_df['Count']))

# Add points
for _, row in merged_df.iterrows():
    # Scale the radius based on the Count value
    radius = row['Count'] / max(merged_df['Count']) * 10
    folium.CircleMarker(
        location=[row['LAT_WGS84'], row['LONG_WGS84']],
        radius=radius,
        color=color_scale(row['Count']),
        fill=True,
        fill_color=color_scale(row['Count']),
        fill_opacity=0.5
    ).add_to(m)

# Add color scale to map
color_scale.add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b19df3c1e2af525802e25afb54153d8a {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b19df3c1e2af525802e25afb54153d8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b19df3c1e2af525802e25afb54153d8a = L.map(
#                 &quot;map_b19df3c1e2af525802e25afb54153d8a&quot;,
#                 {
#                     center: [43.656323, -79.380923],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f0a758c78d94d71981114fed41cc223 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b19df3c1e2af525802e25afb54153d8a);
#
#
#             var circle_marker_e43514b9ab732fc372d97067c2b622d9 = L.circleMarker(
#                 [43.6563225842995, -79.3809227673582],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#800026ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#800026ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b19df3c1e2af525802e25afb54153d8a);
#
#
#             var circle_marker_e6f20a752d4dbd6e23f5f780af8b901f = L.circleMarker(
#                 [43.6666143715903, -79.4117848023346],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d7111fff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d7111fff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.135593220338983, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b19df3c1e2af525802e25afb54153d8a);
#
#
#             var circle_marker_a3ee49a4c7462c9270447c13d84eda2c = L.circleMarker(
#                 [43.6707982509655, -79.3842059245105],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fe9841ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fe9841ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.19774011299435, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b19df3c1e2af525802e25afb54153d8a);
#
#
#             var circle_marker_1bb4212f660f1e66374fd2b342227979 = L.circleMarker(
#                 [43.7327646468606, -79.2645508958054],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fec661ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fec661ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.8606403013182673, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b19df3c1e2af525802e25afb54153d8a);
#
#
#             var circle_marker_518d2ed62cc882546f6093c10c4a6514 = L.circleMarker(
#                 [43.6796730723028, -79.3451524009597],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffdc7cff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffdc7cff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.145009416195857, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b19df3c1e2af525802e25afb54153d8a);
#
#
#             var circle_marker_538f50261ac5bb45f5d891d0867fa7b3 = L.circleMarker(
#                 [43.7043446485815, -79.3978488203008],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffdd7dff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &q

# %% [markdown]
# ## 3. Find the delay with Disorderly Patron

# %%
# Load a shapefile
gdf = gpd.read_file('Criminal Data and Disorderly Patrons Data\subway_stations.shp')

# Display the first few rows of the GeoDataFrame
gdf.head()
# Out:
#       STATION            LINE PLATFORM_L  AVG_PASSEN LINE2 PLATFORM_1  \
# 0     Kipling  Bloor-Danforth          1       53640   NaN        NaN
# 1   Islington  Bloor-Danforth          1       43090   NaN        NaN
# 2  Royal York  Bloor-Danforth          2       19440   NaN        NaN
# 3    Old Mill  Bloor-Danforth          2        5780   NaN        NaN
# 4        Jane  Bloor-Danforth          2       16730   NaN        NaN
#
#   SUBWAY_TRA               ADDRESS  Opened                        geometry
# 0      False  5247 Dundas St. West    1980  POINT (618101.613 4832636.300)
# 1      False   3286 Bloor St. West    1968  POINT (618990.613 4833544.113)
# 2      False   3012 Bloor St. West    1968  POINT (620056.496 4833882.764)
# 3      False   2672 Bloor St. West    1968  POINT (621361.678 4834111.901)
# 4      False   2440 Bloor St. West    1968  POINT (622220.664 4834091.381)

# %%
# create a new dataframe with only station and geometry
selected_df = gdf[['STATION', 'geometry']]
selected_df.head()
# Out:
#       STATION                        geometry
# 0     Kipling  POINT (618101.613 4832636.300)
# 1   Islington  POINT (618990.613 4833544.113)
# 2  Royal York  POINT (620056.496 4833882.764)
# 3    Old Mill  POINT (621361.678 4834111.901)
# 4        Jane  POINT (622220.664 4834091.381)

# %%
# Convert the station name to all upper cases
selected_df['STATION'] = selected_df['STATION'].str.upper()
selected_df.head()
# Out:
#       STATION                        geometry
# 0     KIPLING  POINT (618101.613 4832636.300)
# 1   ISLINGTON  POINT (618990.613 4833544.113)
# 2  ROYAL YORK  POINT (620056.496 4833882.764)
# 3    OLD MILL  POINT (621361.678 4834111.901)
# 4        JANE  POINT (622220.664 4834091.381)

# %%
# Save the dataframe to a csv file
selected_df.to_csv('geometry.csv', index=False)

# %%
# Read the CSV file from the TTC Subway data into a DataFrame
delay = pd.read_csv('Output\TTC_Real_Delay_2014_to_2023.csv')
delay.head()
# Out:
#               Datetime     Day                Station   Code  Min Delay  \
# 0  2018-01-01 00:29:00  Monday  SHEPPARD WEST STATION  MUATC         10
# 1  2018-01-01 01:39:00  Monday         MUSEUM STATION    MUO          6
# 2  2018-01-01 02:09:00  Monday        KIPLING STATION  MUSAN          3
# 3  2018-01-01 02:42:00  Monday        COLLEGE STATION   SUDP          7
# 4  2018-01-01 03:06:00  Monday         WARDEN STATION    MUI          3
#
#    Min Gap Bound Line  Vehicle  \
# 0       15     N  YUS     5986
# 1       11     S  YUS     5781
# 2        7     E   BD     5261
# 3       12     N  YUS     5696
# 4        7     E   BD     5257
#
#                                    Code description  time_interval
# 0                                       ATC Project  00:00 - 01:00
# 1                               Miscellaneous Other  01:00 - 02:00
# 2                                Unsanitary Vehicle  02:00 - 03:00
# 3                                 Disorderly Patron  02:00 - 03:00
# 4  Injured or ill Customer (On Train) - Transported  03:00 - 04:00

# %%
# Filter out the disorderly patron cases
filtered_code = delay[delay['Code'] == 'SUDP']
filtered_code.head()
# Out:
#                Datetime        Day               Station  Code  Min Delay  \
# 3   2018-01-01 02:42:00     Monday       COLLEGE STATION  SUDP          7
# 15  2018-01-01 15:36:00     Monday    SHERBOURNE STATION  SUDP          5
# 39  2018-01-02 09:18:00    Tuesday    FINCH WEST STATION  SUDP          3
# 41  2018-01-02 11:28:00    Tuesday      OLD MILL STATION  SUDP         13
# 66  2018-01-03 12:56:00  Wednesday  ST GEORGE BD STATION  SUDP          7
#
#     Min Gap Bound Line  Vehicle   Code description  time_interval
# 3        12     N  YUS     5696  Disorderly Patron  02:00 - 03:00
# 15       10     E   BD     5269  Disorderly Patron  15:00 - 16:00
# 39        7     S  YUS     6096  Disorderly Patron  09:00 - 10:00
# 41       16     E   BD     5358  Disorderly Patron  11:00 - 12:00
# 66       10     E   BD     5265  Disorderly Patron  12:00 - 13:00

# %%
# Count the number of cases at each subway station
delay_stn = filtered_code['Station'].value_counts()

# Converting the Series to a DataFrame
delay_stn = delay_stn.reset_index()
delay_stn.columns = ['Station', 'Count']

delay_stn.head()
# Out:
#               Station  Count
# 0       BLOOR STATION    370
# 1    EGLINTON STATION    229
# 2  KENNEDY BD STATION    187
# 3    YONGE BD STATION    176
# 4     COXWELL STATION    164

# %%
# Delete " STATION" in the delay_stn data to match the index with the criminal data dataframe
delay_stn['Station'] = delay_stn['Station'].str.replace(" STATION", "", regex=False)

# %%
# Merge stations with corresponding station names
merged_df_delay = pd.merge(delay_stn, selected_df, left_on='Station', right_on='STATION', how='inner')
merged_df_delay.head()
# Out:
#       Station  Count     STATION                        geometry
# 0    EGLINTON    229    EGLINTON  POINT (629021.977 4840533.356)
# 1     COXWELL    164     COXWELL  POINT (635157.330 4838173.966)
# 2     KIPLING    156     KIPLING  POINT (618101.613 4832636.300)
# 3  DAVISVILLE    150  DAVISVILLE  POINT (629140.910 4839583.709)
# 4       FINCH    139       FINCH  POINT (627505.402 4848639.783)

# %%
# Filter out geometry and count from the dataframe above
delay_df = merged_df_delay[['geometry','Count']]
delay_df.head()
# Out:
#                          geometry  Count
# 0  POINT (629021.977 4840533.356)    229
# 1  POINT (635157.330 4838173.966)    164
# 2  POINT (618101.613 4832636.300)    156
# 3  POINT (629140.910 4839583.709)    150
# 4  POINT (627505.402 4848639.783)    139

# %%
delay_df['geometry'].head()
# Out:
# 0    POINT (629021.977 4840533.356)
# 1    POINT (635157.330 4838173.966)
# 2    POINT (618101.613 4832636.300)
# 3    POINT (629140.910 4839583.709)
# 4    POINT (627505.402 4848639.783)
# Name: geometry, dtype: geometry

# %%
import pandas as pd
from pyproj import Proj, Transformer
from shapely.geometry import Point

# Toronto is at UTM zone 17 North
utm_zone = 17
is_south = False

# Create a Transformer object for UTM to WGS84 coordinate transformation
transformer = Transformer.from_proj(
    Proj(proj='utm', zone=utm_zone, ellps='WGS84', south=is_south),
    Proj(proj='latlong', datum='WGS84')
)

# Function to convert UTM to Lat/Lon
def utm_to_latlon(point):
    if point and isinstance(point, Point):
        lon, lat = transformer.transform(point.x, point.y)
        return lat, lon
    else:
        return None, None

# Apply the function to the 'geometry' column
delay_df[['Latitude', 'Longitude']] = delay_df['geometry'].apply(utm_to_latlon).apply(pd.Series)

# Display the DataFrame
print(delay_df)
# Out:
#                           geometry  Count   Latitude  Longitude
# 0   POINT (629021.977 4840533.356)    229  43.706609 -79.398608
# 1   POINT (635157.330 4838173.966)    164  43.684282 -79.323080
# 2   POINT (618101.613 4832636.300)    156  43.637345 -79.535833
# 3   POINT (629140.910 4839583.709)    150  43.698041 -79.397360
# 4   POINT (627505.402 4848639.783)    139  43.779832 -79.415500
# 5   POINT (628695.620 4842566.191)    136  43.724962 -79.402171
# 6   POINT (628695.620 4842566.191)      1  43.724962 -79.402171
# 7   POINT (632306.357 4837276.516)    134  43.676718 -79.358659
# 8   POINT (630307.607 4835962.279)    133  43.665242 -79.383762
# 9   POINT (630370.915 4835534.587)    132  43.661382 -79.383081
# 10  POINT (630555.233 4834978.387)    126  43.656343 -79.380930
# 11  POINT (627716.063 4838010.034)    126  43.684123 -79.415408
# 12  POINT (631521.278 4836950.424)    112  43.673922 -79.368474
# 13  POINT (630698.023 4834540.929)    110  43.652381 -79.379266
# 14  POINT (638642.813 4841232.462)    107  43.711165 -79.279067
# 15  POINT (629671.463 4837959.738)    103  43.683332 -79.391169
# 16  POINT (626913.372 4835583.067)    101  43.662417 -79.425935
# 17  POINT (630660.892 4833804.517)    100  43.645759 -79.379904
# 18  POINT (627514.339 4835782.256)    100  43.664107 -79.418437
# 19  POINT (628303.799 4844693.212)     97  43.744174 -79.406526
# 20  POINT (628086.304 4835966.589)     96  43.665667 -79.411302
# 21  POINT (629885.906 4837265.374)     96  43.677045 -79.388677
# 22  POINT (637843.429 4839378.796)     95  43.694631 -79.289460
# 23  POINT (629802.318 4836509.401)     90  43.670255 -79.389895
# 24  POINT (633395.729 4837636.901)     90  43.679766 -79.345061
# 25  POINT (626149.245 4835327.525)     90  43.660247 -79.435469
# 26  POINT (626009.719 4839678.245)     90  43.699430 -79.436181
# 27  POINT (624793.207 4834950.950)     87  43.657086 -79.452367
# 28  POINT (625578.442 4835178.398)     86  43.659001 -79.442580
# 29  POINT (628406.770 4837006.467)     86  43.674971 -79.407081
# 30  POINT (630873.934 4836757.897)     84  43.672304 -79.376548
# 31  POINT (636844.721 4838729.682)     78  43.688974 -79.302013
# 32  POINT (634580.840 4837995.900)     75  43.682784 -79.330274
# 33  POINT (624825.049 4843520.676)     73  43.734214 -79.449987
# 34  POINT (632820.046 4837463.555)     72  43.678309 -79.352243
# 35  POINT (635967.112 4838437.443)     71  43.686505 -79.312971
# 36  POINT (624191.616 4834764.330)     69  43.655507 -79.459868
# 37  POINT (629514.412 4836180.636)     63  43.667346 -79.393544
# 38  POINT (629779.441 4835353.701)     62  43.659857 -79.390457
# 39  POINT (620056.496 4833882.764)     61  43.648251 -79.511328
# 40  POINT (630818.376 4834182.738)     61  43.649136 -79.377861
# 41  POINT (633978.101 4837809.557)     61  43.681216 -79.337796
# 42  POINT (625331.865 4841497.931)     59  43.715923 -79.444167
# 43  POINT (630107.927 4834358.199)     53  43.650840 -79.386625
# 44  POINT (618990.613 4833544.113)     52  43.645375 -79.524615
# 45  POINT (623684.881 4834584.911)     51  43.653977 -79.466191
# 46  POINT (625579.640 4840794.223)     49  43.709547 -79.441256
# 47  POINT (622220.664 4834091.381)     47  43.649777 -79.484455
# 48  POINT (625014.722 4842562.269)     44  43.725556 -79.447855
# 49  POINT (633087.137 4848247.384)     43  43.775318 -79.346262
# 50  POINT (621361.678 4834111.901)     43  43.650102 -79.495098
# 51  POINT (622874.508 4834305.389)     39  43.651595 -79.476301
# 52  POINT (627911.441 4846611.990)     33  43.761511 -79.410940
# 53  POINT (629762.504 4847231.368)     19  43.766764 -79.387803
# 54  POINT (631441.758 4847727.273)      9  43.770931 -79.366826
# 55  POINT (630655.080 4847517.607)      9  43.769183 -79.376648

# %%
# Create a base map
y = folium.Map(location=[43.656323, -79.380923], zoom_start=12, tiles='CartoDB positron')

# Create a color scale
min_count = delay_df['Count'].min()
max_count = delay_df['Count'].max()
color_scale = cm.linear.Blues_09.scale(min_count, max_count)

# Add points
for _, row in delay_df.iterrows():
    # Scale the radius based on the Count value
    radius = row['Count'] / max_count * 20  # Adjust the multiplier as needed

    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=radius,
        color=color_scale(row['Count']),
        fill=True,
        fill_color=color_scale(row['Count']),
        fill_opacity=0.7
    ).add_to(y)

# Add color scale to map
color_scale.add_to(y)

# Display the map
y
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72b6ce78cf2019c4839d0d5427881176 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72b6ce78cf2019c4839d0d5427881176&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72b6ce78cf2019c4839d0d5427881176 = L.map(
#                 &quot;map_72b6ce78cf2019c4839d0d5427881176&quot;,
#                 {
#                     center: [43.656323, -79.380923],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76341dd63c862e85a3cc4ede7de79965 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_72b6ce78cf2019c4839d0d5427881176);
#
#
#             var circle_marker_9b09e0e19172888f78f53d9fc91e8448 = L.circleMarker(
#                 [43.7066085627419, -79.3986076294025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#08306bff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#08306bff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72b6ce78cf2019c4839d0d5427881176);
#
#
#             var circle_marker_91a6457a1ce40b104661660d4689daaa = L.circleMarker(
#                 [43.68428170572595, -79.32308043145007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2a7abaff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2a7abaff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14.323144104803493, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72b6ce78cf2019c4839d0d5427881176);
#
#
#             var circle_marker_569124e903297ae0207c77a58b8f612f = L.circleMarker(
#                 [43.637344928228096, -79.53583252793143],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3384bfff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3384bfff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.624454148471617, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72b6ce78cf2019c4839d0d5427881176);
#
#
#             var circle_marker_0f3f0948ee1b25a4b9ad38eeac2d13a4 = L.circleMarker(
#                 [43.69804062859581, -79.39735978765313],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3a8bc2ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3a8bc2ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.100436681222707, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72b6ce78cf2019c4839d0d5427881176);
#
#
#             var circle_marker_0ebea45a704fba0f8278ed0e5c03e53e = L.circleMarker(
#                 [43.77983235215268, -79.41550022630153],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4897c9ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4897c9ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.139737991266376, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72b6ce78cf2019c4839d0d5427881176);
#
#
#             var circle_marker_fdc5e694dc83447e2fb15dab2797405c = L.circleMarker(
#                 [43.72496167303776, -79.40217053614262],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4d99cbff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset

# %%
# Create a base map
overlay_map = folium.Map(location=[43.656323, -79.380923], zoom_start=12, tiles='CartoDB positron', width='80%', height='100%')

# Create a color scale for the first map
min_count = delay_df['Count'].min()
max_count = delay_df['Count'].max()
color_scale_1 = cm.linear.Blues_09.scale(min_count, max_count)

# Add points for the first map
for _, row in delay_df.iterrows():
    # Scale the radius based on the Count value
    radius = row['Count'] / max_count * 10

    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=radius,
        color=color_scale_1(row['Count']),
        fill=True,
        fill_color=color_scale_1(row['Count']),
        fill_opacity=0.7
    ).add_to(overlay_map)

# Create a color scale for the second map
color_scale_2 = cm.linear.YlOrRd_09.scale(min(merged_df['Count']), max(merged_df['Count']))

# Add points for the second map
for _, row in merged_df.iterrows():
    # Scale the radius based on the Count value
    radius = row['Count'] / max(merged_df['Count']) * 10
    folium.CircleMarker(
        location=[row['LAT_WGS84'], row['LONG_WGS84']],
        radius=radius,
        color=color_scale_2(row['Count']),
        fill=True,
        fill_color=color_scale_2(row['Count']),
        fill_opacity=0.5
    ).add_to(overlay_map)

# Display the overlay map
overlay_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f6d8ee6393aabae1fff9920c6af26a7 {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f6d8ee6393aabae1fff9920c6af26a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f6d8ee6393aabae1fff9920c6af26a7 = L.map(
#                 &quot;map_0f6d8ee6393aabae1fff9920c6af26a7&quot;,
#                 {
#                     center: [43.656323, -79.380923],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e86b01c26376a7357bab667b7e11d2fe = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0f6d8ee6393aabae1fff9920c6af26a7);
#
#
#             var circle_marker_1772592ad3e1c0657724934e645e0840 = L.circleMarker(
#                 [43.7066085627419, -79.3986076294025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#08306bff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#08306bff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0f6d8ee6393aabae1fff9920c6af26a7);
#
#
#             var circle_marker_7106fc81db011056611ddd0fc499a003 = L.circleMarker(
#                 [43.68428170572595, -79.32308043145007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2a7abaff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2a7abaff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.1615720524017465, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0f6d8ee6393aabae1fff9920c6af26a7);
#
#
#             var circle_marker_3fb7fdffa2dbe34449344abf4577437b = L.circleMarker(
#                 [43.637344928228096, -79.53583252793143],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3384bfff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3384bfff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.812227074235809, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0f6d8ee6393aabae1fff9920c6af26a7);
#
#
#             var circle_marker_38ec45ca72cc4962a07dc15c1c8dc7a1 = L.circleMarker(
#                 [43.69804062859581, -79.39735978765313],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3a8bc2ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3a8bc2ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.550218340611353, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0f6d8ee6393aabae1fff9920c6af26a7);
#
#
#             var circle_marker_e18057182c9be2f9650a928fcadc09dc = L.circleMarker(
#                 [43.77983235215268, -79.41550022630153],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4897c9ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4897c9ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.069868995633188, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0f6d8ee6393aabae1fff9920c6af26a7);
#
#
#             var circle_marker_c0ef828240c0eee61813edecac81f543 = L.circleMarker(
#                 [43.72496167303776, -79.40217053614262],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4d99cbff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4d99cbff&quot;, &quot;fillOpacity&quot;: 0.7
